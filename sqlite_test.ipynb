# %%
import sqlite3

# %%
conn=sqlite3.connect('mydb.db')

# %%
conn

# %%
table_creation_query="""
CREATE TABLE IF NOT EXISTS employees (
    emp_id INTEGER PRIMARY KEY,
    first_name TEXT NOT NULL,
    last_name TEXT NOT NULL,
    email TEXT UNIQUE NOT NULL,
    hire_date DATE NOT NULL,
    salary REAL NOT NULL);
"""

# %%
table_creation_query2="""
CREATE TABLE IF NOT EXISTS customers (
    customer_id INTEGER PRIMARY KEY AUTOINCREMENT,
    first_name TEXT NOT NULL,
    last_name TEXT NOT NULL,
    email TEXT UNIQUE NOT NULL,
    phone TEXT);
"""

# %%
table_creation_query3="""
CREATE TABLE IF NOT EXISTS orders (
    order_id INTEGER PRIMARY KEY AUTOINCREMENT,
    customer_id INTEGER NOT NULL,
    order_date TEXT NOT NULL,
    amount REAL NOT NULL,
    FOREIGN KEY (customer_id) REFERENCES customers(customer_id));
"""

# %%
cursor=conn.cursor()

# %%
#cursor has a method called execute which takes a query as an argument and executes it
cursor.execute(table_creation_query)

# %%
cursor.execute(table_creation_query2)
cursor.execute(table_creation_query3)

# %%
#Insertion

insert_query_emp="""
INSERT INTO employees (emp_id, first_name, last_name, email, hire_date, salary)
VALUES (?, ?, ?, ?, ?, ?);
"""

insert_query_customers="""
INSERT INTO customers (first_name, last_name, email, phone)
VALUES (?, ?, ?, ?);
"""

insert_query_orders="""
INSERT INTO orders (customer_id, order_date, amount)
VALUES (?, ?, ?);
"""

# %%
employee_data = [
    (1, "Sunny", "Singh", "sunny.sv@abc.com", "2020-01-15", 60000.0),
    (2, "Ravi", "Kumar", "ravikumar@gmail.com", "2019-03-10", 55000.0),
    (3, "Anita", "Sharma", "anki@io.com", "2021-07-22", 62000.0),
    (4, "Priya", "Verma", "priyavarm@hotmail.com", "2018-11-05", 58000.0)
]

# %%
customers_data = [
    ("Arjun", "Mehta", "arjun.m@example.com", "9876543210"),
    ("Sara", "Khan", "sara.k@gmail.com", "9821098765"),
    ("Vikram", "Iyer", "viyer@outlook.com", "9900887766"),
    ("Ananya", "Das", "ananya_das@yahoo.com", "9123456789"),
    ("Rohan", "Gupta", "rohan.g@techcorp.in", "9887766554")
]

# %%
orders_data = [
    (1, "2026-05-01", 1250.50),
    (2, "2026-05-02", 450.00),
    (1, "2026-05-05", 2100.75),
    (3, "2026-05-06", 89.99),
    (4, "2026-05-08", 5400.00),
    (5, "2026-05-10", 320.25),
    (2, "2026-05-11", 15.00)
]

# %%
cursor.executemany(insert_query_emp, employee_data)

# %%
# Inserting Customers
# (We skip customer_id because it's AUTOINCREMENT)
cursor.executemany(insert_query_customers, customers_data)

# Inserting Orders
# (We skip order_id because it's AUTOINCREMENT)
cursor.executemany(insert_query_orders, orders_data)

# %%
# Don't forget to commit!
conn.commit()

# %%
#checking
cursor.execute("SELECT * FROM employees;")

# %%
for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'Sunny', 'Singh', 'sunny.sv@abc.com', '2020-01-15', 60000.0)
# (2, 'Ravi', 'Kumar', 'ravikumar@gmail.com', '2019-03-10', 55000.0)
# (3, 'Anita', 'Sharma', 'anki@io.com', '2021-07-22', 62000.0)
# (4, 'Priya', 'Verma', 'priyavarm@hotmail.com', '2018-11-05', 58000.0)

# %%
cursor.execute("SELECT * FROM customers;")

# %%
for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'Arjun', 'Mehta', 'arjun.m@example.com', '9876543210')
# (2, 'Sara', 'Khan', 'sara.k@gmail.com', '9821098765')
# (3, 'Vikram', 'Iyer', 'viyer@outlook.com', '9900887766')
# (4, 'Ananya', 'Das', 'ananya_das@yahoo.com', '9123456789')
# (5, 'Rohan', 'Gupta', 'rohan.g@techcorp.in', '9887766554')
